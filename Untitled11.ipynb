# %%
import pandas as pd
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from datetime import datetime

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder

# %%
df = pd.read_csv('vTargetMailCustomer.csv', encoding='ISO-8859-1')

# %%
pip install chardet

# %%
import chardet

with open('vTargetMailCustomer.csv', 'rb') as f:
    result = chardet.detect(f.read())

df = pd.read_csv('vTargetMailCustomer.csv', encoding=result['encoding'])

# %%
df.head()
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000   NaN        Jon          V
# 1        11001            37           AW00011001   NaN     Eugene          L
# 2        11002            31           AW00011002   NaN      Ruben        NaN
# 3        11003            11           AW00011003   NaN    Christy        NaN
# 4        11004            19           AW00011004   NaN  Elizabeth        NaN
#
#   LastName  NameStyle  BirthDate MaritalStatus  ... HouseOwnerFlag  \
# 0     Yang          0   4/8/1966             M  ...              1
# 1    Huang          0  5/14/1965             S  ...              0
# 2   Torres          0  8/12/1965             M  ...              1
# 3      Zhu          0  2/15/1968             S  ...              0
# 4  Johnson          0   8/8/1968             S  ...              1
#
#   NumberCarsOwned         AddressLine1  AddressLine2                Phone  \
# ...

# %% [markdown]
# # Part **1**

# %%
# Step 1: Feature Selection
selected_features = [
    'CustomerKey', 'GeographyKey', 'CustomerAlternateKey', 'Title', 'FirstName',
    'MiddleName', 'LastName', 'NameStyle', 'BirthDate', 'MaritalStatus',
    # Add more features as needed
]

selected_features += ['BikeBuyer']

df_selected = df[selected_features]

df_selected.to_csv('VTargetBuyers.csv', index=False)


# Make a copy of df_selected and drop 'BikeBuyer' from the copy
df_selected_copy = df_selected.copy()
df_selected_copy.drop(columns=['BikeBuyer'], inplace=True)

# %%
df_selected .head()
# Out:
#    CustomerKey  GeographyKey CustomerAlternateKey Title  FirstName MiddleName  \
# 0        11000            26           AW00011000   NaN        Jon          V
# 1        11001            37           AW00011001   NaN     Eugene          L
# 2        11002            31           AW00011002   NaN      Ruben        NaN
# 3        11003            11           AW00011003   NaN    Christy        NaN
# 4        11004            19           AW00011004   NaN  Elizabeth        NaN
#
#   LastName  NameStyle  BirthDate MaritalStatus  BikeBuyer
# 0     Yang          0   4/8/1966             M          1
# 1    Huang          0  5/14/1965             S          1
# 2   Torres          0  8/12/1965             M          1
# 3      Zhu          0  2/15/1968             S          1
# 4  Johnson          0   8/8/1968             S          1

# %%
# c) Determining the data  value type
nominal_features = ['Title', 'FirstName', 'MiddleName', 'LastName', 'NameStyle', 'MaritalStatus']

# %%
properties = []
for feature in nominal_features:
  properties.append({
    'Property': 'Nominal',
    'Data Type': 'Discrete'
  })

df = pd.DataFrame(properties)

print(df)
# Out:
#   Property Data Type
# 0  Nominal  Discrete
# 1  Nominal  Discrete
# 2  Nominal  Discrete
# 3  Nominal  Discrete
# 4  Nominal  Discrete
# 5  Nominal  Discrete

# %%
# One hot encoding of the columns
df_encoded = pd.get_dummies(df_selected, columns=nominal_features, drop_first=True)

# %%
# Separate numeric and non-numeric columns
numeric_columns = df_selected.select_dtypes(include=['number']).columns
non_numeric_columns = df_selected.select_dtypes(exclude=['number']).columns

# Handle missing values for numeric columns (replace with median)
df_selected[numeric_columns] = df_selected[numeric_columns].fillna(df_selected[numeric_columns].median())

# Handle missing values for non-numeric columns (replace with mode, most frequent)
df_selected[non_numeric_columns] = df_selected[non_numeric_columns].fillna(df_selected[non_numeric_columns].mode().iloc[0])

# Convert 'BirthDate' to 'Age' (assuming 'BirthDate' is in a date format)
current_year = datetime.now().year
df_encoded['BirthDate'] = current_year - pd.to_datetime(df_encoded['BirthDate']).dt.year

# %%
# Save the preprocessed DataFrame to a new CSV file 'PreprocessedData.csv'
df_encoded.to_csv('PreprocessedData.csv', index=False)

# %% [markdown]
# Part 2: Data Preprocessing and Transformation

# %%
# Random Sampling and Bootstrap Sampling
random_sample = df_selected.sample(frac=0.7, random_state=42, replace=False)
bootstrap_sample = df_selected.sample(n=len(df_selected), random_state=42, replace=True)

# %%
#  Calculate Mean/Variance/Standard Deviation for Ordinal Numeric Attributes
ordinal_numeric_features = []  # List the ordinal numeric feature names
df_selected[ordinal_numeric_features].describe()

# %%
# Define a list of numerical feature names based on your dataset
numerical_features = ['CustomerKey', 'GeographyKey', 'CustomerAlternateKey']

# Use the list of numerical features in the describe() function
df_selected[numerical_features].describe()
# Out:
#         CustomerKey  GeographyKey
# count  18484.000000  18484.000000
# mean   20241.500000    257.956287
# std     5336.015523    196.531062
# min    11000.000000      2.000000
# 25%    15620.750000     62.000000
# 50%    20241.500000    240.000000
# 75%    24862.250000    345.000000
# max    29483.000000    654.000000

# %%
plt.figure(figsize=(12, 6))
num_rows = len(numerical_features) // 2 + len(numerical_features) % 2
for i, feature in enumerate(numerical_features):
    plt.subplot(num_rows, 2, i + 1)

    # Convert the column to numeric and handle non-numeric values by setting them to NaN
    df_selected[feature] = pd.to_numeric(df_selected[feature], errors='coerce')

    # Check if the column is numeric before plotting
    if pd.api.types.is_numeric_dtype(df_selected[feature]):
        df_selected[feature].plot(kind='box', vert=False)
        plt.title(feature)
    else:
        plt.title(f"{feature} (Not Numeric)")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
df_selected['BirthDate'] = pd.to_datetime(df_selected['BirthDate'])
df_selected['BirthDate'].hist(bins=20)
plt.title('Distribution of BirthDate')
plt.xlabel('BirthDate')
plt.ylabel('Frequency')
plt.show()

# %%
df_selected.head()
# Out:
#    CustomerKey  GeographyKey  CustomerAlternateKey Title  FirstName  \
# 0        11000            26                   NaN   Mr.        Jon
# 1        11001            37                   NaN   Mr.     Eugene
# 2        11002            31                   NaN   Mr.      Ruben
# 3        11003            11                   NaN   Mr.    Christy
# 4        11004            19                   NaN   Mr.  Elizabeth
#
#   MiddleName LastName  NameStyle  BirthDate MaritalStatus  BikeBuyer
# 0          V     Yang          0 1966-04-08             M          1
# 1          L    Huang          0 1965-05-14             S          1
# 2          A   Torres          0 1965-08-12             M          1
# 3          A      Zhu          0 1968-02-15             S          1
# 4          A  Johnson          0 1968-08-08             S          1

# %%
# Calculate Q1, Median, Q3 for Grouped Data
# Calculate quartiles for features that have been transformed into histograms by discretization
# Convert 'BirthDate' to 'Age' (assuming 'BirthDate' is in a date format)
current_year = pd.Timestamp.now().year
df_selected['BirthDate'] = pd.to_datetime(df_selected['BirthDate'])
df_selected['Age'] = current_year - df_selected['BirthDate'].dt.year

# Calculate Q1, Median, Q3 for the 'Age' column
q1 = df_selected['Age'].quantile(0.25)
median = df_selected['Age'].median()
q3 = df_selected['Age'].quantile(0.75)

print("Q1:", q1)
print("Median:", median)
print("Q3:", q3)
# Out:
# Q1: 53.0
# Median: 60.0
# Q3: 69.0

# %%
#  Identify Features for Binarization (One-Hot Encoding)
# Identify categorical features (nominal or ordinal) that need to be transformed by one-hot encoding
print("Unique values in 'Title':", df_selected['Title'].unique())
print("Unique values in 'MaritalStatus':", df_selected['MaritalStatus'].unique())
features_for_binarization = ['Title', 'MaritalStatus']
# Out:
# Unique values in 'Title': ['Mr.' 'Ms.' 'Mrs.' 'Sr.' 'Ms']
# Unique values in 'MaritalStatus': ['M' 'S']

# %%
#: Normalization or Standardization
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_selected['Age_normalized'] = scaler.fit_transform(df_selected[['Age']])

# %%
# Save the preprocessed DataFrame to a new CSV file
df_selected.to_csv('PreprocessedData.csv', index=False)

# %%
df_selected.head()
# Out:
#    CustomerKey  GeographyKey  CustomerAlternateKey Title  FirstName  \
# 0        11000            26                   NaN   Mr.        Jon
# 1        11001            37                   NaN   Mr.     Eugene
# 2        11002            31                   NaN   Mr.      Ruben
# 3        11003            11                   NaN   Mr.    Christy
# 4        11004            19                   NaN   Mr.  Elizabeth
#
#   MiddleName LastName  NameStyle  BirthDate MaritalStatus  BikeBuyer  Age  \
# 0          V     Yang          0 1966-04-08             M          1   57
# 1          L    Huang          0 1965-05-14             S          1   58
# 2          A   Torres          0 1965-08-12             M          1   58
# 3          A      Zhu          0 1968-02-15             S          1   55
# 4          A  Johnson          0 1968-08-08             S          1   55
#
#    Age_normalized
# 0        0.200000
# 1        0.214286
# 2        0.214286
# 3        0.171429
# ...

# %% [markdown]
# Part 3: Calculating Proximity of Two Binary Object Vectors
# # **With Simple Matching, Jaccard Similarity, Cosine Similarity **

# %%
from sklearn.metrics import pairwise_distances
from scipy.spatial.distance import jaccard

# %%
from sklearn.metrics.pairwise import cosine_similarity


# Calculate Cosine Similarity for the 'Age_normalized' column
customer1_age_normalized = customer1[['Age_normalized']].values.reshape(1, -1)
customer2_age_normalized = customer2[['Age_normalized']].values.reshape(1, -1)
cosine_similarity_value = cosine_similarity(customer1_age_normalized, customer2_age_normalized)

# Print the Cosine Similarity for 'Age_normalized'
print("Cosine Similarity (for 'Age_normalized' column):", cosine_similarity_value[0][0])
# Out:
# Cosine Similarity (for 'Age_normalized' column): 1.0

# %%
def hamming_distance(a, b):
    return sum(ch1 != ch2 for ch1, ch2 in zip(a, b))

# Encode the 'NameStyle' attribute as integers (assuming binary encoding)
customer1_binary_encoded = [int(customer1['NameStyle'])]
customer2_binary_encoded = [int(customer2['NameStyle'])]

hamming_distance_value = hamming_distance(customer1_binary_encoded, customer2_binary_encoded)

print("Hamming Distance for 'NameStyle' attribute:", hamming_distance_value)
# Out:
# Hamming Distance for 'NameStyle' attribute: 0

# %%
binary_attributes = ['NameStyle']

# Convert binary attributes to sets of 0s and 1s
customer1_binary_set = set(customer1[attr].tolist()[0] for attr in binary_attributes)
customer2_binary_set = set(customer2[attr].tolist()[0] for attr in binary_attributes)

intersection = len(customer1_binary_set.intersection(customer2_binary_set))
union = len(customer1_binary_set) + len(customer2_binary_set) - intersection
jaccard_similarity = intersection / union

print("Jaccard Similarity for binary attributes:", jaccard_similarity)
# Out:
# Jaccard Similarity for binary attributes: 1.0

# %% [markdown]
# # **Part 4: Correlation Analysis to Discover Any Relationship between Any Two Features**
# # **by Building a Correlation Matrix **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('vTargetMailCustomer.csv', encoding='ISO-8859-1')

# Step 1: Build a Correlation Matrix for Every Pair of the Features for the entire Data Set
correlation_matrix = df.corr(numeric_only=True)

# %%
# Step 2: Visualize the Correlation Matrix in a Heat Map
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix (All Features)")
plt.show()

# %%
df_bike_buyer_1 = df[df['BikeBuyer'] == 1]
df_bike_buyer_0 = df[df['BikeBuyer'] == 0]

# %%
correlation_matrix_buyer_1 = df_bike_buyer_1.corr(numeric_only=True)

correlation_matrix_buyer_0 = df_bike_buyer_0.corr(numeric_only=True)

# %%
# Out:
# Correlation between Age and YearlyIncome for Bike Buyer = 1: 0.16979385899380495
# Correlation between Age and YearlyIncome for Bike Buyer = 0: 0.16989013060140626

# %%
# Access the correlation value between 'Age' and 'YearlyIncome' for both subsets
correlation_age_income_buyer_1 = correlation_matrix_buyer_1.loc['Age', 'YearlyIncome']
correlation_age_income_buyer_0 = correlation_matrix_buyer_0.loc['Age', 'YearlyIncome']

# Print the correlation values
print("Correlation between Age and YearlyIncome for Bike Buyer = 1:", correlation_age_income_buyer_1)
print("Correlation between Age and YearlyIncome for Bike Buyer = 0:", correlation_age_income_buyer_0)
# Out:
# Correlation between Age and YearlyIncome for Bike Buyer = 1: 0.16979385899380495
# Correlation between Age and YearlyIncome for Bike Buyer = 0: 0.16989013060140626
