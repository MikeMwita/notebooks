# %%
import requests
from bs4 import BeautifulSoup
import re
import certifi

# Set up a session with certificate verification using certifi
session = requests.Session()
session.verify = certifi.where()

urls = [
    "https://www.edx.org/course/data-science-machine-learning",
    "https://en.wikipedia.org/wiki/Engineering",
    "http://my.clevelandclinic.org/research",
    "https://en.wikipedia.org/wiki/Data_mining",
    "https://en.wikipedia.org/wiki/Data_mining#Data_mining",
]

# Function to save the text content of a web page to a text file
def save_webpage_text(url, output_file):
    try:
        if "eecs.csuohio.edu" in url:
            response = session.get(url, verify=False)
        else:
            response = session.get(url)  # Verify other URLs
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            for script in soup(['script', 'style']):
                script.extract()
            text_content = soup.get_text()
            text_content = re.sub(r'\s+', ' ', text_content).strip()
            with open(output_file, 'w', encoding='utf-8') as file:
                file.write(text_content)
            print(f"Saved content from {url} to {output_file}")
        else:
            print(f"Failed to retrieve content from {url}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Loop through the URLs and save content to text files
for index, url in enumerate(urls):
    output_file = f"webpage_{index}.txt"
    save_webpage_text(url, output_file)
# Out:
# Saved content from https://www.edx.org/course/data-science-machine-learning to webpage_0.txt
# Saved content from https://en.wikipedia.org/wiki/Engineering to webpage_1.txt
# Saved content from http://my.clevelandclinic.org/research to webpage_2.txt
# Saved content from https://en.wikipedia.org/wiki/Data_mining to webpage_3.txt
# Saved content from https://en.wikipedia.org/wiki/Data_mining#Data_mining to webpage_4.txt

# %% [markdown]
# 2. Preprocessing

# %%
import requests
from bs4 import BeautifulSoup
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import nltk
nltk.download('stopwords')

# Define a function to preprocess text
def preprocess_text(text):
    # Remove special symbols, punctuation, and question marks
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)

    # Convert text to lowercase
    text = text.lower()

    # Tokenize the text
    words = text.split()

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Apply stemming using the Porter Stemmer
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]

    # Join the preprocessed words back into a text
    preprocessed_text = " ".join(words)

    return preprocessed_text

# Function to save the preprocessed text content of a web page to a text file
def save_preprocessed_webpage_text(url, output_file):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            # Parse HTML content
            soup = BeautifulSoup(response.text, 'html.parser')
            # Remove scripts and style elements from the parsed content
            for script in soup(['script', 'style']):
                script.extract()
            # Extract and clean the text content
            text_content = soup.get_text()
            # Remove extra spaces and newline characters
            text_content = re.sub(r'\s+', ' ', text_content).strip()
            # Preprocess the text
            preprocessed_text = preprocess_text(text_content)
            # Save the preprocessed text to a text file
            with open(output_file, 'w', encoding='utf-8') as file:
                file.write(preprocessed_text)
            print(f"Saved preprocessed content from {url} to {output_file}")
        else:
            print(f"Failed to retrieve content from {url}")
    except Exception as e:
        print(f"An error occurred: {e}")

# Loop through the URLs and save preprocessed content to text files
for index, url in enumerate(urls):
    output_file = f"preprocessed_webpage_{index}.txt"
    save_preprocessed_webpage_text(url, output_file)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Saved preprocessed content from https://www.edx.org/course/data-science-machine-learning to preprocessed_webpage_0.txt
# Saved preprocessed content from https://en.wikipedia.org/wiki/Engineering to preprocessed_webpage_1.txt
# Saved preprocessed content from http://my.clevelandclinic.org/research to preprocessed_webpage_2.txt
# Saved preprocessed content from https://en.wikipedia.org/wiki/Data_mining to preprocessed_webpage_3.txt
# Saved preprocessed content from https://en.wikipedia.org/wiki/Data_mining#Data_mining to preprocessed_webpage_4.txt

# %% [markdown]
#  Count Term Frequency

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)

# %%
import collections
from nltk.util import ngrams

# Function for preprocessing and counting term frequencies
def preprocess_and_count_term_frequencies(text):
    # Preprocessing
    # Remove special symbols, punctuation, and question marks
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)
    # Convert text to lowercase
    text = text.lower()
    # Tokenize the text
    words = text.split()
    # Remove stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]
    # Apply stemming using the Porter Stemmer
    stemmer = PorterStemmer()
    words = [stemmer.stem(word) for word in words]

    # Term frequency counting
    # Tokenize the preprocessed text into terms (unigrams) and phrases (bi-grams and tri-grams)
    tokens = text.split()
    unigrams = tokens
    bigrams = list(ngrams(tokens, 2))
    trigrams = list(ngrams(tokens, 3))

    # Count the term frequencies
    term_frequencies = {
        "unigrams": collections.Counter(unigrams),
        "bigrams": collections.Counter(bigrams),
        "trigrams": collections.Counter(trigrams),
    }

    return term_frequencies

# Read the preprocessed text files and process them
for index, url in enumerate(urls):
    preprocessed_text = ""  # Initialize an empty string to store preprocessed text

    # Read the preprocessed text from the corresponding file
    with open(f"preprocessed_webpage_{index}.txt", 'r', encoding='utf-8') as file:
        preprocessed_text = file.read()

    # Call the preprocessing and term frequency counting function
    term_frequencies = preprocess_and_count_term_frequencies(preprocessed_text)

    # Print or store the term frequencies as needed
    print(f"Term frequencies for {url}:")
    print("Unigrams:", term_frequencies["unigrams"])
    print("Bigrams:", term_frequencies["bigrams"])
    print("Trigrams:", term_frequencies["trigrams"])
# Out:
# Term frequencies for https://www.edx.org/course/data-science-machine-learning:
# Unigrams: Counter({'data': 22, 'cours': 18, 'learn': 17, 'edx': 16, 'scienc': 14, 'machin': 14, 'harvardx': 10, 'boot': 9, 'research': 8, 'recommend': 7, 'use': 7, 'system': 6, 'algorithm': 6, 'certif': 6, 'popular': 5, 'offer': 5, 'program': 5, 'inform': 5, 'movi': 4, 'oct': 4, 'build': 4, 'includ': 4, 'also': 4, 'take': 4, 'may': 4, 'onlin': 4, 'learner': 4, 'person': 4, 'us': 4, 'new': 3, 'receiv': 3, 'youll': 3, 'comput': 3, 'predict': 3, 'servic': 3, 'speech': 3, 'analysi': 3, 'train': 3, 'part': 3, 'ask': 3, 'code': 3, 'statement': 3, 'honor': 3, 'polici': 3, 'share': 3, 'identifi': 3, 'harvard': 3, 'region': 3, 'busi': 3, 'softwar': 3, 'search': 2, 'analysisharvardx': 2, 'learningdata': 2, 'one': 2, 'hour': 2, 'per': 2, 'enrol': 2, 'dec': 2, 'relat': 2, 'enrollenrol': 2, 'start': 2, 'process': 2, 'recognit': 2, 'princip': 2, 'compon': 2, 'regular': 2, 'overtrain': 2, 'avoid': 2, 'crossvalid': 2, 'skill': 2, 'profession': 2, 'perform': 2, 'frequent': 2, 'abid': 2, 'term': 2, 'correct': 2, 'action': 2, 'violat': 2, 'regist': 2, 'particip': 2, 'expos': 2, 'purpos': 2, 'be
1, 'deni': 1, 'benefit': 1, 'discrimin': 1, 'expect': 1, 'nondiscrimin': 1, 'sexual': 1, 'concern': 1, 'harvardxharvardedu': 1, 'andor': 1, 'experi': 1, 'formshow': 1, 'morewho': 1, 'courseunfortun': 1, 'resid': 1, 'follow': 1, 'abl': 1, 'iran': 1, 'cuba': 1, 'crimea': 1, 'ukrain': 1, 'sought': 1, 'offic': 1, 'foreign' ...
# Bigrams: Counter({('data', 'scienc'): 10, ('machin', 'learn'): 8, ('scienc', 'machin'): 6, ('recommend', 'system'): 6, ('movi', 'recommend'): 4, ('system', 'learn'): 3, ('learn', 'algorithm'): 3, ('cours', 'part'): 3, ('harvardx', 'cours'): 3, ('person', 'identifi'): 3, ('offer', 'cours'): 3, ('analysisharvardx', 'data'): 2, ('machin', 'learningdata'): 2, ('hour', 'per'): 2, ('enrol', 'cours'): 2, ('enrollenrol', 'start'): 2, ('start', 'oct'): 2, ('algorithm', 'use'): 2, ('use', 'data'): 2, ('speech', 'recognit'): 2, ('certif', 'program'): 2, ('program', 'data'): 2, ('popular', 'machin'): 2, ('princip', 'compon'): 2, ('compon', 'analysi'): 2, ('build', 'movi'): 2, ('learn', 'train'): 2, ('train', 'data'): 2, ('profession', 'certif'): 2, ('frequent', 'ask'): 2, ('edx', 'honor'): 2, ('honor', 'code'): 2, ('correct', 'action'): 2, ('research', 'may'): 2, ('identifi', 'inform'): 2, ('countri', 'region'): 2, ('us', 'offer'): 2, ('manag', 'boot'): 2, ('learn', 'edx'): 1, ('edx', 'skip'): 1, ('skip', 'main'): 1, ('main', 'contenttoggl'): 1, ('contenttoggl', 'mobil'): 1, ('mobil', 'menusign'): 1, ('menusign', 'inregist'): 1, ('inregist', 'freecoursesal'): 1, ('freecoursesal', 'cours'): 1, ('cours', 'programsprogram'): 1, ('programsprogram', 'degreesboot'): 1, ('degreesboot', 'campsdegre'): 1, ('campsdegre', 'programsnewboot'): 1, ('programsnewboot', 'campsschool'): 1, ('campsschool', 'partnersschool'): 1, ('partnersschool', 'partnersedx'): 1, ('partnersedx', 'businesssearch'): 1, ('businesssearch', 'cours'): 1, ('cours', 'programssubmit'): 1, ('programssubmit', 'search'): 1, ('search', 'querysubmit'): 1, ('querysubmit', 'search'): 1, ('search', 'queryhomelearndata'): 1, ('queryhomelearndata', 'analysisharvardx'): 1, ('learningdata', 'analysisharvardx'): 1, ('machin', 'learning43'): 1, ('learning43', 'stars36'): 1, ('stars36', 'ratingsbuild'): 1, ('ratingsbuild', 'movi'): 1, ('learn', 'scienc'): 1, ('scienc', 'behind'): 1, ('behind', 'one'): 1, ('one', 'popular'): 1, ('popular', 'success'): 1, ('success', 'data'): 1, ('scienc', 'techniques8'): 1, ('techniques8', 'weeks2â\x80\x934'): 1, ('weeks2â\x80\x934', 'hour'): 1, ('per', 'weekselfpacedprogress'): 1, ('weekselfpacedprogress', 'speedfreeopt'): 1, ('speedfreeopt', 'upgrad'): 1, ('upgrad', 'availablechoos'): 1, ('availablechoos', 'session494422'): 1, ('session494422', 'alreadi'): 1, ('alreadi', 'enrol'): 1, ('cours', 'session'): 1, ('session', 'end'): 1, ('end', 'archivedopen'): 1, ('archivedopen', 'new'): 1, ('new', 'tabstart'): 1, ('tabstart', 'oct'): 1, ('oct', '18end'): 1, ('18end', 'dec'): 1, ('dec', '20enrollstart'): 1, ('20enrollstart', 'oct'): 1, ('oct', '18enrolli'): 1, ('18enrolli', 'would'): 1, ('would', 'like'): 1, ('like', 'receiv'): 1, ('receiv', 'email'): 1, ('email', 'harvardx'): 1, ('harvardx', 'learn'): 1, ('learn', 'offer'): 1, ('offer', 'relat'): 1, ('relat', 'data'): 1, ('learningdata', 'scienc'): 1, ('machin', 'learningaboutaboutwhat'): 1, ('learningaboutaboutwhat', 'youll'): 1, ('youll', 'learninstructorsfaqsway'): 1, ('learninstructorsfaqsway', 'enrollenrol'): 1, ('oct', '18about'): 1, ('18about', 'courseskip'): 1, ('courseskip', 'courseperhap'): 1, ('courseperhap', 'popular'): 1, ('popular', 'data'): 1, ('scienc', 'methodolog'): 1, ('methodolog', 'come'): 1, ('come', 'machin'): 1, ('learn', 'distinguish'): 1, ('distinguish', 'machin'): 1, ('learn', 'comput'): 1, ('comput', 'guid'): 1, ('guid', 'decis'): 1, ('decis', 'process'): 1, ('process', 'build'): 1, ('build', 'predict'): 1, ('predict', 'algorithm'): 1, ('data', 'popular'): 1, ('popular', 'product'): 1, ('product', 'use'): 1, ('use', 'machin'): 1, ('learn', 'includ'): 1, ('includ', 'handwrit'): 1, ('handwrit', 'reader'): 1, ('reader', 'implement'): 1, ('implement', 'postal'): 1, ('postal', 'servic'): 1, ('servic', 'speech'): 1, ('recognit', 'movi'): 1, ('system', 'spam'): 1, ('spam', 'detector'): 1, ('detector', 'coursepart'): 1, ('coursepart', 'ofourprofession'): 1, ('ofourprofession', 'certif'): 1, ('sc ...
# Trigrams: Counter({('data', 'scienc', 'machin'): 5, ('movi', 'recommend', 'system'): 4, ('recommend', 'system', 'learn'): 3, ('machin', 'learn', 'algorithm'): 3, ('scienc', 'machin', 'learn'): 2, ('analysisharvardx', 'data', 'scienc'): 2, ('scienc', 'machin', 'learningdata'): 2, ('enrollenrol', 'start', 'oct'): 2, ('certif', 'program', 'data'): 2, ('program', 'data', 'scienc'): 2, ('popular', 'machin', 'learn'): 2, ('princip', 'compon', 'analysi'): 2, ('build', 'movi', 'recommend'): 2, ('system', 'learn', 'train'): 2, ('edx', 'honor', 'code'): 2, ('person', 'identifi', 'inform'): 2, ('us', 'offer', 'cours'): 2, ('machin', 'learn', 'edx'): 1, ('learn', 'edx', 'skip'): 1, ('edx', 'skip', 'main'): 1, ('skip', 'main', 'contenttoggl'): 1, ('main', 'contenttoggl', 'mobil'): 1, ('contenttoggl', 'mobil', 'menusign'): 1, ('mobil', 'menusign', 'inregist'): 1, ('menusign', 'inregist', 'freecoursesal'): 1, ('inregist', 'freecoursesal', 'cours'): 1, ('freecoursesal', 'cours', 'programsprogram'): 1, ('cours', 'programsprogram', 'degreesboot'): 1, ('programsprogram', 'degreesboot', 'campsdegre'): 1, ('degreesboot', 'campsdegre', 'programsnewboot'): 1, ('campsdegre', 'programsnewboot', 'campsschool'): 1, ('programsnewboot', 'campsschool', 'partnersschool'): 1, ('campsschool', 'partnersschool', 'partnersedx'): 1, ('partnersschool', 'partnersedx', 'businesssearch'): 1, ('partnersedx', 'businesssearch', 'cours'): 1, ('businesssearch', 'cours', 'programssubmit'): 1, ('cours', 'programssubmit', 'search'): 1, ('programssubmit', 'search', 'querysubmit'): 1, ('search', 'querysubmit', 'search'): 1, ('querysubmit', 'search', 'queryhomelearndata'): 1, ('search', 'queryhomelearndata', 'analysisharvardx'): 1, ('queryhomelearndata', 'analysisharvardx', 'data'): 1, ('machin', 'learningdata', 'analysisharvardx'): 1, ('learningdata', 'analysisharvardx', 'data'): 1, ('scienc', 'machin', 'learning43'): 1, ('machin', 'learning43', 'stars36'): 1, ('learning43', 'stars36', 'ratingsbuild'): 1, ('stars36', 'ratingsbuild', 'movi'): 1, ('ratingsbuild', 'movi', 'recommend'): 1, ('system', 'learn', 'scienc'): 1, ('learn', 'scienc', 'behind'): 1, ('scienc', 'behind', 'one'): 1, ('behind', 'one', 'popular'): 1, ('one', 'popular', 'success'): 1, ('popular', 'success', 'data'): 1, ('success', 'data', 'scienc'): 1, ('data', 'scienc', 'techniques8'): 1, ('scienc', 'techniques8', 'weeks2â\x80\x934'): 1, ('techniques8', 'weeks2â\x80\x934', 'hour'): 1, ('weeks2â\x80\x934', 'hour', 'per'): 1, ('hour', 'per', 'weekselfpacedprogress'): 1, ('per', 'weekselfpacedprogress', 'speedfreeopt'): 1, ('weekselfpacedprogress', 'speedfreeopt', 'upgrad'): 1, ('speedfreeopt', 'upgrad', 'availablechoos'): 1, ('upgrad', 'availablechoos', 'session494422'): 1, ('availablechoos', 'session494422', 'alreadi'): 1, ('session494422', 'alreadi', 'enrol'): 1, ('alreadi', 'enrol', 'cours'): 1, ('enrol', 'cours', 'session'): 1, ('cours', 'session', 'end'): 1, ('session', 'end', 'archivedopen'): 1, ('end', 'archivedopen', 'new'): 1, ('archivedopen', 'new', 'tabstart'): 1, ('new', 'tabstart', 'oct'): 1, ('tabstart', 'oct', '18end'): 1, ('oct', '18end', 'dec'): 1, ('18end', 'dec', '20enrollstart'): 1, ('dec', '20enrollstart', 'oct'): 1, ('20enrollstart', 'oct', '18enrolli'): 1, ('oct', '18enrolli', 'would'): 1, ('18enrolli', 'would', 'like'): 1, ('would', 'like', 'receiv'): 1, ('like', 'receiv', 'email'): 1, ('receiv', 'email', 'harvardx'): 1, ('email', 'harvardx', 'learn'): 1, ('harvardx', 'learn', 'offer'): 1, ('learn', 'offer', 'relat'): 1, ('offer', 'relat', 'data'): 1, ('relat', 'data', 'scienc'): 1, ('machin', 'learningdata', 'scienc'): 1, ('learningdata', 'scienc', 'machin'): 1, ('scienc', 'machin', 'learningaboutaboutwhat'): 1, ('machin', 'learningaboutaboutwhat', 'youll'): 1, ('learningaboutaboutwhat', 'youll', 'learninstructorsfaqsway'): 1, ('youll', 'learninstructorsfaqsway', 'enrollenrol'): 1, ('learninstructorsfaqsway', 'enrollenrol', 'start'): 1, ('start', 'oct', '18about'): 1, ('oct', '18about', ' ...
number': 7, 'cambridg': 7, 'foundat': 7, 'aeronaut': 7, 'organ': 7, 'inform': 7, 'code': 7, 'scientist': 7, 'know': 7, 'complex': 7, 'januari': 7, '31': 7, '23': 7, '2011': 7, 'content': 6, 'move': 6, 'page': 6, 'subsect': 6, 'age': 6, 'outlin': 6, 'categori': 6, 'infrastructur': 6, 'combin': 6, 'econom': 6, 'life': 6, 'time': 6, 'mesopotamia': 6, 'like': 6, 'contain': 6, 'furnac': 6, 'antikythera': 6, 'train': 6, 'spin': 6, 'section': 6, 'allow': 6, 'provid': 6, 'physicist': 6, 'experiment': 6, 'jame': 6, 'michael': 6, 'aircraft': 6, 'optic': 6, 'fiber': 6, 'transport': 6, 'equip': 6, 'nuclear': 6, 'integr': 6, 'unsourc': 6, 'remov': 6, 'understand': 6, 'chang': 6, 'statement': 6, '16': 6, '2012': 6, '13': 6, '4': 6, '20': 6, '2013': 6, '19': 6, '5': 6, 'david': 6, 'arab': 6, '2014': 6, 'wikipedia': 5, 'era': 5, 'solv': 5, 'context': 5, 'relationship': 5, 'english': 5, 'see': 5, 'portal': 5, 'increas': 5, 'vehicl': 5, 'energi': 5, 'type': 5, 'council': 5, 'util': 5, 'lever': 5, 'empir': 5, 'pyramid': 5, 'skill': 5, 'appear': 5, 'around': 5, '2000': 5, 'evid': 5, 'store': 5, 'employ': 5, 'blast': 5, 'greek': 5, 'gear': 5, 'wide': 5, 'wind': 5, 'pump': 5, 'turbin': 5, 'describ': 5, 'fundament': 5, 'standard': 5, 'sometim': 5, 'form': 5, 'smeaton': 5, 'respons': 5, 'led': 5, 'miner': 5, 'late': 5, 'fuel': 5, 'sever': 5, 'georg': 5, 'motor': 5, 'dedic': 5, 'role': 5, 'deal': 5, 'concept': 5, 'specialti': 5, 'petroleum': 5, 'public': 5, 'tradit': 5, 'circuit': 5, 'control': 5, ...
# Bigrams: Counter({('archiv', 'origin'): 45, ('civil', 'engin'): 19, ('wayback', 'machin'): 18, ('univers', 'press'): 16, ('main', 'articl'): 13, ('mechan', 'engin'): 13, ('branch', 'engin'): 11, ('engin', 'design'): 10, ('retriev', 'septemb'): 10, ('press', 'isbn'): 10, ('engin', 'main'): 9, ('steam', 'engin'): 8, ('electr', 'engin'): 8, ('chemic', 'engin'): 8, ('scienc', 'engin'): 8, ('engin', 'topic'): 8, ('profession', 'engin'): 8, ('2020', 'retriev'): 8, ('retriev', 'march'): 8, ('unit', 'state'): 7, ('electron', 'engin'): 7, ('aerospac', 'engin'): 7, ('topic', 'list'): 7, ('engin', 'educ'): 7, ('engin', 'archiv'): 7, ('origin', 'april'): 7, ('industri', 'revolut'): 6, ('antikythera', 'mechan'): 6, ('use', 'engin'): 6, ('human', 'bodi'): 6, ('retriev', 'august'): 6, ('2021', 'retriev'): 6, ('2007', 'retriev'): 6, ('retriev', 'octob'): 6, ('art', 'engin'): 6, ('appli', 'scienc'): 5, ('engin', 'practic'): 5, ('larg', 'scale'): 5, ('machin', 'tool'): 5, ('engin', 'civil'): 5, ('electr', 'electron'): 5, ('engin', 'electr'): 5, ('list', '
# Trigrams: Counter({('engin', 'main', 'articl'): 9, ('univers', 'press', 'isbn'): 7, ('archiv', 'origin', 'april'): 7, ('engin', 'topic', 'list'): 6, ('engin', 'archiv', 'origin'): 6, ('archiv', 'origin', 'august'): 5, ('archiv', 'origin', 'januari'): 5, ('oxford', 'univers', 'press'): 5, ('archiv', 'origin', 'februari'): 5, ('main', 'branch', 'engin'): 4, ('archiv', 'origin', 'juli'): 4, ('archiv', 'origin', 'septemb'): 4, ('2020', 'wayback', 'machin'): 4, ('retriev', 'octob', '13'): 4, ('octob', '13', '2019'): 4, ('august', '1', '2020'): 4, ('archiv', 'origin', 'decemb'): 4, ('john', 'hopkin', 'univers'): 4, ('hopkin', 'univers', 'press'): 4, ('retriev', 'septemb', '15'): 4, ('septemb', '15', '2019'): 4, ('retriev', 'march', '30'): 4, ('march', '30', '2007'): 4, ('2007', 'wayback', 'machin'): 4, ('2007', 'retriev', 'march'): 4, ('move', 'sidebar', 'hide'): 3, ('electr', 'electron', 'engin'): 3, ('engin', 'civil', 'engin'): 3, ('engin', 'mechan', 'engin'): 3, ('engin', 'geolog', 'engin'): 3, ('learn', 'remov', 'templat'): 3, ('remov', 'templat', 'messag'): 3, ('nation', 'societi', 'profession'): 3, ('societi', 'profession', 'engin'): 3, ('creat', 'world', 'never'): 3, ('engin', 'practic', 'engin'): 3, ('engin', 'know', 'know'): 3, ('function', 'human', 'bodi'): 3, ('leonardo', 'da', 'vinci'): 3, ('2020', 'retriev', 'septemb'): 3, ('univers', 'press', 'p'): 3, ('archiv', 'origin', 'may'): 3, ('retriev', 'june', '19'): 3, ('cambridg', 'univers', 'press'): 3, ('civil', 'mechan', 'electr'): 3, ('mechan', 'electr', 'chemic'): 3, ('archiv', 'origin', 'pdf'): 3, ('2019', 'retriev', 'septemb'): 3, ('june', '19', '2014'): 3, ('archiv', 'august', '1'): 3, ('1', '2020', 'wayback'): 3, ('branch', 'engin', 'toggl'): 2, ('branch', 'engin', 'subsect'): 2, ('toggl', 'tabl', 'content'): 2, ('readview', 'sourceview', 'histori'): 2, ('special', 'field', 'engin'): 2, ('term', 'engin', 'deriv'): 2, ('deriv', 'latin', 'ingenium'): 2, ('engin', 'council', 'profession'): 2, ('council', 'profession', 'develop'): 2, ('mental', 'power', 'henc'): 2, ('power', 'henc', 'clever'): 2, ('ancient', 'near', 'east'): 2, ('lower', 'cost', 'iron'): 2, ('late', '19th', 'centuri'): 2, ('chemic', 'new', 'industri'): 2, ('josiah', 'willard', 'gibb'): 2, ('engin', 'usual', 'train'): 2, ('civil', 'engin', 'electr'): 2, ('engin', 'electr', 'engin'): 2, ('engin', 'chemic', 'engin'): 2, ('physic', 'chemistri', 'biolog'): 2, ('engin', 'environ
, 'advocaci': 1, 'advanc': 1, 'foundat': 1, 'power': 1, 'today': 1, 'save': 1, 'live': 1, 'continu': 1, 'show': 1, '247': 1, '8663204573': 1, '2164442200': 1, 'request': 1, 'facebook': 1, 'twitter': 1, 'youtub': 1, 'instagram': 1, 'linkedin': 1, 'pinterest': 1, 'snapchat': 1, 'action': 1, 'accessaccept': 1, 'insuranceev': 1, 'calendarfinanci': 1, 'assistanceg': 1, 'clinicpay': 1, 'bill': 1, 'onlineref': 1, 'patientphon': 1, 'directoryvirtu': 1, 'second': 1, 'opinionsvirtu': 1, 'blog': 1, 'app': 1 ...
# Bigrams: Counter({('cleveland', 'clinic'): 27, ('research', 'cleveland'): 8, ('nurs', 'research'): 8, ('clinic', 'research'): 6, ('research', 'innov'): 5, ('comput', 'life'): 4, ('life', 'scienc'): 4, ('direct', 'patient'): 3, ('cleveland', 'clinic’'): 3, ('groundbreak', 'research'): 3, ('offic', 'nurs'): 3, ('import', 'updat'): 2, ('100', 'year'): 2, ('year', 'cleveland'): 2, ('clevelandclinicorg', 'find'): 2, ('find', 'doctor'): 2, ('doctor', 'locat'): 2, ('locat', 'direct'): 2, ('patient', 'visitor'): 2, ('visitor', 'health'): 2, ('health', 'librari'): 2, ('librari', 'institut'): 2, ('institut', 'depart'): 2, ('depart', 'appoint'): 2, ('patient', 'care'): 2, ('translat', 'research'): 2, ('diagnost', 'test'): 2, ('pathogen', 'research'): 2, ('innov', 'district'): 2, ('research', 'center'): 2, ('center', 'institut'): 2, ('lerner', 'research'): 2, ('research', 'institut'): 2, ('center', 'comput'): 2, ('scienc', 'use'): 2, ('visit', 'comput'): 2, ('coordin', 'center'): 2, ('research', 'program'): 2, ('best', 'practic'): 2, ('idea', 'research'): 2, ('nurs', 'practic'): 2, ('want', 'support'): 2, ('support', 'groundbreak'): 2, ('innov', 'cleveland'): 1, ('clinic', 'import'): 1, ('updat', 'close'): 1, ('close', 'import'): 1, ('updat', 'come'): 1, ('come', 'cleveland'): 1, ('clinic', 'locat'): 1, ('locat', 'e'): 1, ('e', '100th'): 1, ('100th', 'street'): 1, ('street', 'cleveland'): 1, ('clinic', 'main'): 1, ('main', 'campu'): 1, ('campu', 'close'): 1, ('close', 'hillcrest'): 1, ('hillcrest', 'cancer'): 1, ('cancer', 'center'): 1, ('center', 'checkin'): 1, ('checkin', 'chang'): 1, ('chang', 'cole'): 1, ('cole', 'eye'): 1, ('eye', 'entranc'): 1, ('entranc', 'close'): 1, ('close', 'visit'): 1, ('visit', 'covid19'): 1, ('covid19', 'inform'): 1, ('inform', '8002232273'): 1, ('8002232273', '100'): 1, ('clinic', 'mychart'): 1, ('mychart', 'need'): 1, ('need', 'help'): 1, ('help', 'give'): 1, ('give', 'career'): 1, ('career', 'search'): 1, ('search', 'search'): 1, ('search', 'cleveland'): 1, ('clinic', 'menu'): 1, ('menu', 'clevelandclinicorg'): 1, ('appoint', 'mychartne'): 1, ('mychartne', 'help'): 1, ('help', 'call'): 1, ('call', 'addit'): 1, ('addit', 'assist'): 1, ('assist', '8002232273'): 1, ('8
inic', 'import'): 1, ('clinic', 'import', 'updat'): 1, ('import', 'updat', 'close'): 1, ('updat', 'close', 'import'): 1, ('close', 'import', 'updat'): 1, ('import', 'updat', 'come'): 1, ('updat', 'come', 'cleveland'): 1, ('come', 'cleveland', 'clinic'): 1, ('cleveland', 'clinic', 'locat'): 1, ('clinic', 'locat', 'e'): 1, ('locat', 'e', '100th'): 1, ('e', '100th', 'street'): 1, ('100th', 'street', 'cleveland'): 1, ('street', 'cleveland', 'clinic'): 1, ('cleveland', 'clinic', 'main'): 1, ('clinic', 'main', 'campu'): 1, ('main', 'campu', 'close'): 1, ('campu', 'close', 'hillcrest'): 1, ('close', 'hillcrest', 'cancer'): 1, ('hillcrest', 'cancer', 'center'): 1, ('cancer', 'center', 'checkin'): 1, ('center', 'checkin', 'chang'): 1, ('checkin', 'chang', 'cole'): 1, ('chang', 'cole', 'eye'): 1, ('cole', 'eye', 'entranc'): 1, ('eye', 'entranc', 'close'): 1, ('entranc', 'close', 'visit'): 1, ('close', 'visit', 'covid19'): 1, ('visit', 'covid19', 'inform'): 1, ('covid19', 'inform', '8002232273'): 1, ('inform', '8002232273', '100'): 1, ('8002232273', '100', 'year'): 1, ('year', 'cleveland', 'clinic'): 1, ('cleveland', 'clinic', 'mychart'): 1, ('clinic', 'mychart', 'need'): 1, ('mychart', 'need', 'help'): 1, ('need', 'help', 'give'): 1, ('help', 'give', 'career'): 1, ('give', 'career', 'search'): 1, ('career', 'search', 'search'): 1, ('search', 'search', 'cleveland'): 1, ('search', 'cleveland', 'clinic'): 1, ('cleveland', 'clinic', 'menu'): 1, ('clinic', 'menu', 'clevelandclinicorg'): 1, ('menu', 'clevelandclinicorg', 'find'): 1, ('depart', 'appoint', 'mychartne'): 1, ('appoint', 'mychartne', 'help'): 1, ('mychartne', 'help', 'call'): 1, ('help', 'call', 'addit'): 1, ('call', 'addit', 'assist'): 1, ('addit', 'assist', '8002232273'): 1, ('assist', '8002232273', 'clevelandclinicorg'): 1, ('8002232273', 'clevelandclinicorg', 'find'): 1, ('depart', 'appoint', 'research'): 1, ('appoint', 'research', 'cleveland'): 1, ('cleveland', 'clinic', 'focus'): 1, ('clinic', 'focus', 'cuttingedg'): 1, ('focus', 'cuttingedg', 'research'): 1, ('cuttingedg', 'research', 'character'): 1, ('research', 'character', 'diagnosi'): 1, ('character', 'diagnosi', 'treatment'): 1, ('diagnosi', 'treatment', 'broad'): 1, ('treatment', 'broad', 'spectrum'): 1, ('broad', 'spectrum', 'diseas'): 1, ('spectrum', 'diseas', 'condit'): 1, ('diseas', 'condit', 'learn'): 1, ('condit', 'learn', 'cleveland'): 1, ('learn', 'cleveland', 'clinic'): 1, ('cleveland', 'clinic', 'caregiv'): 1, ('clinic', 'caregiv', 'pursu'): 1, ('caregiv', 'pursu', 'guid'): 1, ('pursu', 'guid', 'principl'): 1, ('guid', 'principl', '‘patient'): 1, ('principl', '‘patient', 'first’'): 1, ('‘patient', 'first’', 'improv'): 1, ('first’', 'improv', 'patient'): 1, ('improv', 'patient', 'care'): 1, ('patient', 'care', 'research'): 1, ('care', 'research', 'futur'): 1, ('research', 'futur', 'healthcar'): 1, ('futur', 'healthcar', 'research'): 1, ('healthcar', 'research', 'sinc'): 1, ('research' ...
4, ('larg', 'data'): 4, ('anomali', 'detect'): 4, ('vector', 'machin'): 4, ('mine', 'practic'): 4, ('cluster', 'analysi'): 4, ('data', 'collect'): 4, ('mine', 'use'): 4, ('mine', 'knowledg'): 4, ('see', 'also'): 4, ('content', 'mine'): 4, ('fair', 'use'): 4, ('natur', 'languag'): 4, ('big', 'data'): 4, ('2011', 'data'): 4, ('morgan', 'kaufmann'): 4, ('archiv', 'pdf'): 4, ('pdf', 'origin'): 4, ('kdnugget', 'methodolog'): 4, ('methodolog', 'poll'): 4, ('poll', 'archiv'): 4, ('retriev', '14'): 4, ('14', 'novemb'): 4, ('move', 'sidebar'): 3, ('sidebar', 'hide'): 3, ('privaci', 'concern'): 3, ('pattern', 'larg'): 3, ('web', 'mine'): 3, ('mine', 'see'): 3, ('reinforc', 'learn'): 3, ('decis', 'tree'): 3, ('support', 'vector'): 3, ('learn', 'statist'): 3, ('statist', 'learn'): 3, ('extract', 'inform'): 3, ('learn', 'tool'): 3, ('tool', 'techniqu'): 3, ('mine', 'step'): 3, ('data', 'use'): 3, ('data', 'prepar'): 3, ('analysi', 'data'): 3, ('data', 'dredg'): 3, ('data', 'data'): 3, ('data', 'warehous'): 3, ('rule', 'learn'): 3, ('structur', 'data'): 3, ('model', 'data'): 3, ('test', 'set'): 3, ('intern', 'confer'): 3, ('confer', 'data'): 3, ('mine', 'applic'): 3, ('particular', 'data'): 3, ('nation', 'secur'): 3, ('data', 'aggreg'): 3, ('safe', 'harbor'): 3, ('biotech', 'busi'): 3, ('busi', 'week'): 3, ('text', 'data'): 3, ('learn', 'softwar'): 3, ('languag', 'process'): 3, ('text', 'mine'): 3, ('learn', 'data'): 3, ('b', 'c'): 3, ('concept', 'techniqu'): 3, ('origin', '20221009'): 3, ('witten', 'ian'): 3, ('ian', 'h'): 3, ('frank', 'eib'): 3, ('eib', 'hall'): 3, ('hall', 'mark'): 3, ('machin', 'gregori'): 3, ('new', 'york'): 3, ('2014', 'retriev'): 3, ('extract', 'transform'): 3, ('transform', 'load'): 3, ('theori', 'comput'): 3, ('main', 'menu'): 2, ('concern', 'ethic'): 2, ('opensourc', 'data'): 2, ('datamin', 'softwar'): 2, ('toggl', 'tabl'): 2, ('tabl', 'content'): 2, ('readeditview', 'histori'): 2, ('wikimedia', 'common'): 2, ('process', 'extract'): 2, ('extract', 'discov'): 2, ('discov', 'pattern'): 2, ('supervis', 'learn'): 2, ('learn', 'unsupervis'): 2, ('unsupervis', 'learn'): 2, ('learn', 'reinforc'): 2, ('data', 'clean'): 2, ('structur', 'predict'): 2, ('learn', 'supervis'): 2, ('tree', 'ensembl'): 2, ('artifici', 'neural'): 2, ('factor', 'analysi'): 2, ('deep', 'learn'): 2, ('list', 'dataset'): 2, ('comput', 'vision'): 2, ('goal', 'extract'): 2, ('mine', 'analysi'): 2, ('analysi', 'step'): 2, ('step', 'knowledg'): 2, ('extract', 'pattern'): 2, ('amount', 'data'): 2, ('data', 'extract'): 2, ('mine', 'ad'): 2, ('larg', 'scale'): 2, ('intellig', 'machin'): 2, ('mine', 'task'): 2, ('group', 'data'): 2, ('data', 'record'): 2, ('data', 'may'): 2, ('may', 'use'): 2, ('predict', 'analyt'): 2, ('collect', 'data'): 2, ('kdd', 'process'): 2, ('use', 'test'): 2, ('data', 'fish'): 2, ('fish', 'data'): 2, ('analyz', 'data'): 2, ('publish', 'review'): 2, ('review', 'econom'): 2, ('term', 'use'): 2, ('becam', 'popular'): 2, ('pattern', 'data'): 2, ('regress', 'analysi'): 2, ('learn', 'neural'): 2, ('analysi', 'genet'): 2, ('genet', 'algorithm'): 2, ('databas', 'manag'): 2, ('way', 'dat ...
# Trigrams: Counter({('data', 'mine', 'softwar'): 10, ('term', 'data', 'mine'): 8, ('data', 'mine', 'process'): 5, ('knowledg', 'discoveri', 'databas'): 5, ('decis', 'support', 'system'): 5, ('practic', 'machin', 'learn'): 5, ('exampl', 'data', 'mine'): 5, ('data', 'mine', 'algorithm'): 5, ('knowledg', 'discoveri', 'data'): 5, ('mine', 'softwar', 'provid'): 5, ('data', 'mine', 'concept'): 5, ('data', 'mine', 'data'): 4, ('data', 'mine', 'use'): 4, ('data', 'mine', 'knowledg'): 4, ('mine', 'knowledg', 'discoveri'): 4, ('discoveri', 'data', 'mine'): 4, ('2011', 'data', 'mine'): 4, ('archiv', 'pdf', 'origin'): 4, ('kdnugget', 'methodolog', 'poll'): 4, ('methodolog', 'poll', 'archiv'): 4, ('retriev', '14', 'novemb'): 4, ('14', 'novemb', '2014'): 4, ('move', 'sidebar', 'hide'): 3, ('larg', 'data', 'set'): 3, ('support', 'vector', 'machin'): 3, ('data', 'mine', 'practic'): 3, ('mine', 'practic', 'machin'): 3, ('machin', 'learn', 'tool'): 3, ('learn', 'tool', 'techniqu'): 3, ('data', 'mine', 'step'): 3, ('use', 'data', 'mine'): 3, ('associ', 'rule', 'learn'): 3, ('confer', 'data', 'mine'): 3, ('mine', 'data', 'mine'): 3, ('biotech', 'busi', 'week'): 3, ('machin', 'learn', 'softwar'): 3, ('natur', 'languag', 'process'): 3, ('learn', 'data', 'mine'): 3, ('mine', 'concept', 'techniqu'): 3, ('pdf', 'origin', '20221009'): 3, ('witten', 'ian', 'h'): 3, ('frank', 'eib', 'hall'): 3, ('eib', 'hall', 'mark'): 3, ('wayback', 'machin', 'gregori'): 3, ('machin', 'gregori', 'piatetskyshapiro'): 3, ('novemb', '2014', 'retriev'): 3, ('extract', 'transform', 'load'): 3, ('opensourc', 'data', 'mine'): 2, ('toggl', 'tabl', 'content'): 2, ('process', 'extract', 'discov'): 2, ('extract', 'discov', 'pattern'): 2, ('discov', 'pattern', 'larg'): 2, ('pattern', 'larg', 'data'): 2, ('supervis', 'learn', 'unsupervis'): 2, ('learn', 'unsupervis', 'learn'): 2, ('learn', 'reinforc', 'learn'): 2, ('decis', 'tree', 'ensembl'): 2, ('artifici', 'neural', 'network'): 2, ('machin', 'learn', 'statist'): 2, ('data', 'mine', 'analysi'): 2, ('step', 'knowledg', 'discoveri'): 2, ('data', 'mine', 'ad'): 2, ('artifici', 'intellig', 'machin'): 2, ('data', 'mine', 'task'): 2, ('data', 'collect', 'data'): 2, ('data', 'analysi', 'data'): 2, ('analysi', 'data', 'mine'): 2, ('data', 'fish', 'data'): 2, ('learn', 'neural', 'network'): 2, ('analysi', 'genet', 'algorithm'): 2, ('discoveri', 'databas', 'kdd'): 2, ('standard', 'process', 'data'): 2, ('process', 'data', 'mine'): 2, ('data', 'mine', 'crispdm'): 2, ('data', 'mine', 'standard'): 2, ('target', 'data', 'set'): 2, ('data', 'set', 'must'): 2, ('train', 'learn', 'pattern'): 2, ('appli', 'test', 'set'): 2, ('learn', 'pattern', 'meet'): 2, ('pattern', 'meet', 'desir'): 2, ('meet', 'desir', 'standard'): 2, ('confer', '–', 'acm'): 2, ('confer', 'knowledg', 'discoveri'): 2, ('data', 'mine', 'applic'): 2, ('particular', 'data', 'mine'): 2, ('main', 'articl', 'exampl'): 2, ('articl', 'exampl', 'data'): 2, ('data', 'mine', 'see'): 2, ('mine', 'see', 'also'): 2, ('see', 'also', 'categoryappli'): 2, ('also', 'categoryappli', 'data'): 2, ('categoryappli', 'data', 'mine'): 2, ('nation', 'secur', 'agenc'): 2, ('situat', 'unit', 'statesedit'): 2, ('allow', 'content', 'mine'): 2, ('uk', 'copyright', 'law'): 2, ('mine', 'machin', 'learn'): 2, ('softwar', 'applicationsedit', 'follow'): 2, ('applicationsedit', 'follow', 'applic'): 2, ('follow', 'applic', 'avail'): 2, ('java', 'program', 'languag'): 2, ('machin', 'learn', 'algorithm'): 2, ('data', 'mine', 'tool'): 2, ('data', 'mine', 'busi'): 2, ('miner', 'data', 'mine'): 2, ('custom', 'ml', 'model'): 2, ('inform', 'extract', 'inform'): 2, ('hasti', 'trevor', 'tibshirani'): 2, ('trevor', 'tibshirani', 'robert'): 2, ('tibshirani', 'robert', 'friedman'): 2, ('robert', 'friedman', 'jerom'): 2, ('element', 'statist', 'learn'): 2, ('statist', 'learn', 'data'): 2, ('data', 'mine', 'infer'): 2, ('mine', 'infer', 'predict'): 2, ('1996', 'data', 'mine'): 2, ('pdf', 'archiv', 'pdf'): 2, ('origin', '20221009', ...
# Term frequencies for https://en.wikipedia.org/wiki/Data_mining#Data_mining:
# Unigrams: Counter({'data': 258, 'mine': 160, 'learn': 69, 'machin': 47, 'softwar': 40, 'comput': 40, 'use': 39, 'inform': 38, 'analysi': 36, 'archiv': 32, 'model': 29, 'process': 26, 'languag': 25, 'pattern': 25, 'origin': 24, 'set': 23, 'databas': 22, 'knowledg': 22, 'retriev': 21, 'privaci': 20, 'statist': 20, 'system': 20, 'algorithm': 19, 'network': 18, 'discoveri': 18, 'applic': 17, 'term': 17, 'extract': 16, 'intellig': 16, 'busi': 16, 'isbn': 16, 'law': 15, 'method': 15, 'confer': 15, 'also': 14, 'research': 14, 'secur': 14, 'wayback': 14, 'tool': 13, 'predict': 13, 'may': 13, 'exampl': 13, 'practic': 12, 'provid': 12, '2014': 12, 'program': 12, 'content': 11, 'unit': 11, 'scienc': 11, 'manag': 11, '–': 11, 'search': 10, 'larg': 10, 'cluster': 10, 'structur': 10, 'decis': 10, 'support': 10, 'transform': 10
 3, 'tree': 3, 'ensembl': 3, 'random': 3, 'bay': 3, 'factor': 3, 'condit': 3, 'hidden': 3, 'vision': 3, 'ml': 3, 'goal': 3, 'complex': 3, 'visual': 3, 'wareh': 3, 'eg': 3, 'cover': 3, 'scale': 3, 'interest': 3, 'record': 3, 'depend': 3, 'indic': 3, 'interpret': 3, 'hypothes': 3, 'effect': 3, 'dredg': 3, 'fish': 3, 'sampl': 3, 'michael': 3, 'lovel': 3, 'turn': 3, 'topic': 3, 'current': 3, 'increas': 3, 'technolog': 3, 'storag': 3, 'genet': 3, 'defin': 3, '3': 3, 'conduct': 3, 'semma': 3, 'peopl': 3, 'sever': 3, 'enough': 3, 'contain': 3, 'sourc': 3, 'identif': 3, 'relationship': 3, 'attempt': 3, 'classifi': 3, 'find': 3, 'futur': 3, 'behavior': 3, 'caus': 3, 'perform': 3, 'overfit': 3, 'final': 3, 'desir': 3, ' ...
# Bigrams: Counter({('data', 'mine'): 128, ('machin', 'learn'): 26, ('data', 'set'): 16, ('archiv', 'origin'): 15, ('knowledg', 'discoveri'): 13, ('wayback', 'machin'): 13, ('mine', 'softwar'): 11, ('neural', 'network'): 9, ('term', 'data'): 9, ('artifici', 'intellig'): 7, ('mine', 'data'): 7, ('data', 'analysi'): 7, ('novemb', '2014'): 7, ('unit', 'state'): 6, ('exampl', 'data'): 6, ('use', 'data'): 6, ('mine', 'concept'): 6, ('program', 'languag'): 6, ('copyright', 'law'): 5, ('associ', 'rule'): 5, ('mine', 'process'): 5, ('comput', 'scienc'): 5, ('discoveri', 'databas'): 5, ('decis', 'support'): 5, ('support', 'system'): 5, ('busi', 'intellig'): 5, ('practic', 'machin'): 5, ('gregori', 'piatetskyshapiro'): 5, ('mine', 'algorithm'): 5, ('discoveri', 'data'): 5, ('learn', 'pattern'): 5, ('softwar', 'provid'): 5, ('inform', 'system'): 5, ('softwar', 'applic'): 4, ('larg', 'data'): 4, ('anomali', 'detect'): 4, ('vector', 'machin'): 4, ('mine', 'practic'): 4, ('cluster', 'analysi'): 4, ('data', 'collect'): 4, ('mine', 'use'): 4, ('mine', 'knowledg'): 4, ('see', 'also'): 4, ('content', 'mine'): 4, ('fair', 'use'): 4, ('natur', 'languag'): 4, ('big', 'data'): 4, ('2011', 'data'): 4, ('morgan', 'kaufmann'): 4, ('archiv', 'pdf'): 4, ('pdf', 'origin'): 4, ('kdnugget', 'methodolog'): 4, ('methodolog', 'poll'): 4, ('poll', 'archiv'): 4, ('retriev', '14'): 4, ('14', 'novemb'): 4, ('move', 'sidebar'): 3, ('sidebar', 'hide'): 3, ('privaci', 'concern'): 3, ('pattern', 'larg'): 3, ('web', 'mine'): 3, ('mine', 'see'): 3, ('reinforc', 'learn'): 3, ('decis', 'tree'): 3, ('support', 'vector'): 3, ('learn', 'statist'): 3, ('statist', 'learn'): 3, ('extract', 'inform'): 3, ('learn', 'tool'): 3, ('tool', 'techniqu'): 3, ('mine', 'step'): 3, ('data', 'use'): 3, ('data', 'prepar'): 3, ('analysi', 'data'): 3, ('data', 'dredg'): 3, ('data', 'data'): 3, ('data', 'warehous'): 3, ('rule', 'learn'): 3, ('structur', 'data'): 3, ('model', 'data'): 3, ('test', 'set'): 3, ('intern', 'confer'): 3, ('confer', 'data'): 3, ('mine', 'applic'): 3, ('particular', 'data'): 3, ('nation', 'secur'): 3, ('data', 'aggreg'): 3, ('safe', 'harbor'): 3, ('biotech', 'busi'): 3, ('busi', 'week'): 3, ('text', 'data'): 3, ('learn', 'softwar'): 3, ('languag', 'process'): 3, ('text', 'mine'): 3, ('learn', 'data'): 3, ('b', 'c'): 3, ('concept', 'techniqu'): 3, ('origin', '20221009'): 3, ('witten', 'ian'): 3, ('ian', 'h'): 3, ('frank', 'eib'): 3, ('eib', 'hall'): 3, ('hall', 'mark'): 3, ('machin', 'gregori'): 3, ('new', 'york'): 3, ('2014', 'retriev'): 3, ('extract', 'transform'): 3, ('transform', 'load'): 3, ('theori', 'comput'): 3, ('main', 'menu'): 2, ('concern', 'ethic'): 2, ('opensourc', 'data'): 2, ('datamin', 'softwar'): 2, ('toggl', 'tabl'): 2, ('tabl', 'content'): 2, ('readeditview', 'histori'): 2, ('wikimedia', 'common'): 2, ('process', 'extract'): 2, ('extract', 'discov'): 2, ('discov', 'pattern'): 2, ('supervis', 'learn'): 2, ('learn', 'unsupervis'): 2, ('unsupervis', 'learn'): 2, ('learn', 'reinforc'): 2, ('data', 'clean'): 2, ('structur', 'predict'): 2, ('learn', 'supervis'): 2, ('tree', 'ensembl'): 2, ('artifici', 'neural'): 2, ('factor', 'analysi'): 2, ('deep', 'learn'): 2, ('list', 'dataset'): 2, ('comput', 'vision'): 2, ('goal', 'extract'): 2, ('mine', 'analysi'): 2, ('analysi', 'step'): 2, ('step', 'knowledg'): 2, ('extract', 'pattern'): 2, ('amount', 'data'): 2, ('data', 'extract'): 2, ('mine', 'ad'): 2, ('larg', 'scale'): 2, ('intellig', 'machin'): 2, ('mine', 'task'): 2, ('group', 'data'): 2, ('data', 'record'): 2, ('data', 'may'): 2, ('may', 'use'): 2, ('predict', 'analyt'): 2, ('collect', 'data'): 2, ('kdd', 'process'): 2, ('use', 'test'): 2, ('data', 'fish'): 2, ('fish', 'data'): 2, ('analyz', 'data'): 2, ('publish', 'review'): 2, ('review', 'econom'): 2, ('term', 'use'): 2, ('becam', 'popular'): 2, ('pattern', 'data'): 2, ('regress', 'analysi'): 2, ('learn', 'neural'): 2, ('analysi', 'genet'): 2, ('genet', 'algorithm'): 2, ('databas', 'manag'): 2, ('way', 'dat ...
# Trigrams: Counter({('data', 'mine', 'softwar'): 10, ('term', 'data', 'mine'): 8, ('data', 'mine', 'process'): 5, ('knowledg', 'discoveri', 'databas'): 5, ('decis', 'support', 'system'): 5, ('practic', 'machin', 'learn'): 5, ('exampl', 'data', 'mine'): 5, ('data', 'mine', 'algorithm'): 5, ('knowledg', 'discoveri', 'data'): 5, ('mine', 'softwar', 'provid'): 5, ('data', 'mine', 'concept'): 5, ('data', 'mine', 'data'): 4, ('data', 'mine', 'use'): 4, ('data', 'mine', 'knowledg'): 4, ('mine', 'knowledg', 'discoveri'): 4, ('discoveri', 'data', 'mine'): 4, ('2011', 'data', 'mine'): 4, ('archiv', 'pdf', 'origin'): 4, ('kdnugget', 'methodolog', 'poll'): 4, ('methodolog', 'poll', 'archiv'): 4, ('retriev', '14', 'novemb'): 4, ('14', 'novemb', '2014'): 4, ('move', 'sidebar', 'hide'): 3, ('larg', 'data', 'set'): 3, ('support', 'vector', 'machin'): 3, ('data', 'mine', 'practic'): 3, ('mine', 'practic', 'machin'): 3, ('machin', 'learn', 'tool'): 3, ('learn', 'tool', 'techniqu'): 3, ('data', 'mine', 'step'): 3, ('use', 'data', 'mine'): 3, ('associ', 'rule', 'learn'): 3, ('confer', 'data', 'mine'): 3, ('mine', 'data', 'mine'): 3, ('biotech', 'busi', 'week'): 3, ('machin', 'learn', 'softwar'): 3, ('natur', 'languag', 'process'): 3, ('learn', 'data', 'mine'): 3, ('mine', 'concept', 'techniqu'): 3, ('pdf', 'origin', '20221009'): 3, ('witten', 'ian', 'h'): 3, ('frank', 'eib', 'hall'): 3, ('eib', 'hall', 'mark'): 3, ('wayback', 'machin', 'gregori'): 3, ('machin', 'gregori', 'piatetskyshapiro'): 3, ('novemb', '2014', 'retriev'): 3, ('extract', 'transform', 'load'): 3, ('opensourc', 'data', 'mine'): 2, ('toggl', 'tabl', 'content'): 2, ('process', 'extract', 'discov'): 2, ('extract', 'discov', 'pattern'): 2, ('discov', 'pattern', 'larg'): 2, ('pattern', 'larg', 'data'): 2, ('supervis', 'learn', 'unsupervis'): 2, ('learn', 'unsupervis', 'learn'): 2, ('learn', 'reinforc', 'learn'): 2, ('decis', 'tree', 'ensembl'): 2, ('artifici', 'neural', 'network'): 2, ('machin', 'learn', 'statist'): 2, ('data', 'mine', 'analysi'): 2, ('step', 'knowledg', 'discoveri'): 2, ('data', 'mine', 'ad'): 2, ('artifici', 'intellig', 'machin'): 2, ('data', 'mine', 'task'): 2, ('data', 'collect', 'data'): 2, ('data', 'analysi', 'data'): 2, ('analysi', 'data', 'mine'): 2, ('data', 'fish', 'data'): 2, ('learn', 'neural', 'network'): 2, ('analysi', 'genet', 'algorithm'): 2, ('discoveri', 'databas', 'kdd'): 2, ('standard', 'process', 'data'): 2, ('process', 'data', 'mine'): 2, ('data', 'mine', 'crispdm'): 2, ('data', 'mine', 'standard'): 2, ('target', 'data', 'set'): 2, ('data', 'set', 'must'): 2, ('train', 'learn', 'pattern'): 2, ('appli', 'test', 'set'): 2, ('learn', 'pattern', 'meet'): 2, ('pattern', 'meet', 'desir'): 2, ('meet', 'desir', 'standard'): 2, ('confer', '–', 'acm'): 2, ('confer', 'knowledg', 'discoveri'): 2, ('data', 'mine', 'applic'): 2, ('particular', 'data', 'mine'): 2, ('main', 'articl', 'exampl'): 2, ('articl', 'exampl', 'data'): 2, ('data', 'mine', 'see'): 2, ('mine', 'see', 'also'): 2, ('see', 'also', 'categoryappli'): 2, ('also', 'categoryappli', 'data'): 2, ('categoryappli', 'data', 'mine'): 2, ('nation', 'secur', 'agenc'): 2, ('situat', 'unit', 'statesedit'): 2, ('allow', 'content', 'mine'): 2, ('uk', 'copyright', 'law'): 2, ('mine', 'machin', 'learn'): 2, ('softwar', 'applicationsedit', 'follow'): 2, ('applicationsedit', 'follow', 'applic'): 2, ('follow', 'applic', 'avail'): 2, ('java', 'program', 'languag'): 2, ('machin', 'learn', 'algorithm'): 2, ('data', 'mine', 'tool'): 2, ('data', 'mine', 'busi'): 2, ('miner', 'data', 'mine'): 2, ('custom', 'ml', 'model'): 2, ('inform', 'extract', 'inform'): 2, ('hasti', 'trevor', 'tibshirani'): 2, ('trevor', 'tibshirani', 'robert'): 2, ('tibshirani', 'robert', 'friedman'): 2, ('robert', 'friedman', 'jerom'): 2, ('element', 'statist', 'learn'): 2, ('statist', 'learn', 'data'): 2, ('data', 'mine', 'infer'): 2, ('mine', 'infer', 'predict'): 2, ('1996', 'data', 'mine'): 2, ('pdf', 'archiv', 'pdf'): 2, ('origin', '20221009', ...

# %% [markdown]
# [link text](https://) Creating Document Vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer
import os

# Define the 7 topics
topics = ["research", "data", "mining", "analytics", "data mining", "machine learning", "deep learning"]

# Initialize a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(vocabulary=topics)

# Create an empty list to store document vectors
document_vectors = []

# Iterate through the preprocessed text of each document
for index, url in enumerate(urls):
    preprocessed_text = ""  # Initialize an empty string to store preprocessed text

    # Define the filename for the preprocessed text
    preprocessed_filename = f"preprocessed_webpage_{index}.txt"

    # Check if the file exists
    if os.path.exists(preprocessed_filename):
        # Read the preprocessed text from the file
        with open(preprocessed_filename, 'r', encoding='utf-8') as file:
            preprocessed_text = file.read()

        # Calculate TF-IDF scores for the document
        tfidf_scores = tfidf_vectorizer.fit_transform([preprocessed_text]).toarray()[0]

        # Create a dictionary where keys are topics and values are TF-IDF scores
        document_vector = {topic: tfidf_scores[i] for i, topic in enumerate(topics)}

        # Append the document vector to the list
        document_vectors.append(document_vector)

# Print or store the document vectors as needed
for i, doc_vector in enumerate(document_vectors):
    print(f"Document {i + 1} Vector:")
    for topic, score in doc_vector.items():
        print(f"{topic}: {score}")
# Out:
# Document 1 Vector:
# research: 0.3417430630867044
# data: 0.939793423488437
# mining: 0.0
# analytics: 0.0
# data mining: 0.0
# machine learning: 0.0
# deep learning: 0.0
# Document 2 Vector:
# research: 0.9889363528682975
# data: 0.14834045293024462
# mining: 0.0
# analytics: 0.0
# data mining: 0.0
# machine learning: 0.0
# deep learning: 0.0
# Document 3 Vector:
# research: 0.9996714309094813
# data: 0.0256326007925508
# mining: 0.0
# analytics: 0.0
# data mining: 0.0
# machine learning: 0.0
# deep learning: 0.0
# Document 4 Vector:
# research: 0.05418182247688608
# data: 0.998493585645472
# mining: 0.0038701301769204343
# analytics: 0.007740260353840869
# data mining: 0.0
# machine learning: 0.0
# deep learning: 0.0
# Document 5 Vector:
# research: 0.05418182247688608
# data: 0.998493585645472
# mining: 0.0038701301769204343
# analytics: 0.007740260353840869
# data mining: 0.0
# machine learning: 0.0
# deep learning: 0.0

# %% [markdown]
#  Topic Words and Phrases

# %%
# Define the topics
topics = ["research", "data", "mining", "analytics", "data mining", "machine learning", "deep learning"]

# Create a dictionary to store relevant terms or phrases for each topic
topic_terms = {topic: [] for topic in topics}

# Iterate through the available preprocessed text files
for index, url in enumerate(urls):
    preprocessed_file = f"preprocessed_webpage_{index}.txt"

    # Check if the preprocessed file exists
    if os.path.exists(preprocessed_file):
        # Read the preprocessed text from the file
        with open(preprocessed_file, 'r', encoding='utf-8') as file:
            preprocessed_text = file.read()

        # Tokenize the preprocessed text
        tokens = preprocessed_text.split()

        # Iterate through the topics
        for topic in topics:
            # Define a list of terms or phrases associated with the current topic
            # Adjust these lists as per your domain or dataset
            topic_keywords = {
                "research": ["research", "study", "investigation", "survey"],
                "data": ["data", "information", "dataset", "statistics"],
                "mining": ["mining", "extraction", "knowledge discovery"],
                "analytics": ["analytics", "analysis", "statistical analysis"],
                "data mining": ["data mining", "pattern recognition", "association rules"],
                "machine learning": ["machine learning", "algorithms", "deep learning"],
                "deep learning": ["deep learning", "neural networks", "artificial intelligence"]
            }

            # Check if any of the topic keywords are present in the text
            for keyword in topic_keywords[topic]:
                if keyword in tokens:
                    topic_terms[topic].append(keyword)

# Print or store the relevant terms or phrases for each topic
for topic, terms in topic_terms.items():
    print(f"Relevant terms for {topic}: {', '.join(terms)}")
# Out:
# Relevant terms for research: research, research, survey, research, research, survey, research, survey
# Relevant terms for data: data, dataset, data, data, data, dataset, data, dataset
# Relevant terms for mining:
# Relevant terms for analytics:
# Relevant terms for data mining:
# Relevant terms for machine learning:
# Relevant terms for deep learning:

# %% [markdown]
# Part 2: Data Transformation for Topic Analysis of Documents (Webpages)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import os
import numpy as np

# Define the 7 topics listed
topics = ["research", "data", "mining", "analytics", "data mining", "machine learning", "deep learning"]

# Initialize a TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(vocabulary=topics)

# Create an empty list to store document vectors
document_vectors = []

# Iterate through the preprocessed text of each document
for index, url in enumerate(urls):
    preprocessed_text = ""  # Initialize an empty string to store preprocessed text

    # Define the filename for the preprocessed text
    preprocessed_filename = f"preprocessed_webpage_{index}.txt"

    # Check if the file exists
    if os.path.exists(preprocessed_filename):
        # Read the preprocessed text from the file
        with open(preprocessed_filename, 'r', encoding='utf-8') as file:
            preprocessed_text = file.read()

        # Calculate TF-IDF scores for the document
        tfidf_scores = tfidf_vectorizer.fit_transform([preprocessed_text]).toarray()[0]

        # Append the document vector to the list
        document_vectors.append(tfidf_scores)

# Normalize each document vector
normalized_vectors = [doc / np.linalg.norm(doc) if np.linalg.norm(doc) != 0 else doc for doc in document_vectors]

cosine_similarity_matrix = cosine_similarity(normalized_vectors, normalized_vectors)

print("      doc1     doc2     doc3     doc4      ")
for i, row in enumerate(cosine_similarity_matrix):
    doc_name = f"doc{i + 1}"
    row_str = " ".join([f"{score:.4f}" for score in row])
    print(f"{doc_name} {row_str}")
# Out:
#       doc1     doc2     doc3     doc4
# doc1 1.0000 0.4774 0.3657 0.9569 0.9569
# doc2 0.4774 1.0000 0.9924 0.2017 0.2017
# doc3 0.3657 0.9924 1.0000 0.0798 0.0798
# doc4 0.9569 0.2017 0.0798 1.0000 1.0000
# doc5 0.9569 0.2017 0.0798 1.0000 1.0000
